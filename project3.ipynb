# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import os
import copy
import seaborn as sns

# %%
cd
# Out:
# C:\Users\ziyi Su
# C:\Users\ziyi Su\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# C:\Users\ziyi Su\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:428: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
a = r'C:\Users\ziyi Su\aae718'
os.chdir(a)

# %%
df1 =  pd.read_csv('project3_k.csv', parse_dates = ["DATE"], date_format = '%Y-%m-%d')
df1 = df1.set_index("DATE")

# %%
df1 = df1[(df1['NAME'] == 'KUNMING, CH') | (df1['NAME'] == 'MIAMI BEACH, FL US')]
df1_t = df1[df1['TMAX'].notna()]

# %%
kunming_data = df1_t[df1_t['NAME'] == 'KUNMING, CH']
miami_data = df1_t[df1_t['NAME'] == 'MIAMI BEACH, FL US']

plt.figure(figsize=(10, 6))
plt.plot(kunming_data.index, kunming_data['TMAX'], label='Kunming')
plt.plot(miami_data.index, miami_data['TMAX'], label='Miami')
plt.title('The comparsion of max temperature neyween kunming and miami')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.legend()
plt.savefig('project3-1.png')
plt.show()
plt.close()

# %%
df_2 = df1_t.loc[df1_t.index.year.isin([2020, 2021])]
kunming_data2 = df_2[df_2['NAME'] == 'KUNMING, CH']
miami_data2 = df_2[df_2['NAME'] == 'MIAMI BEACH, FL US']

plt.figure(figsize=(10, 6))
plt.plot(kunming_data2.index, kunming_data2['TMAX'], label='Kunming')
plt.plot(miami_data2.index, miami_data2['TMAX'], label='Miami')
plt.title('The comparsion of max temperature neyween kunming and miami in 2020 to 2021')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.legend()
plt.savefig('project3-2.png')
plt.show()
plt.close()

# %%
df2 =  pd.read_csv('project3_m.csv', parse_dates = ["DATE"], date_format = '%Y-%m-%dT%H:%M:%S')
df2 = df2.set_index("DATE")
# Out:
# C:\Users\ziyi Su\AppData\Local\Temp\ipykernel_7468\3545381101.py:1: DtypeWarning: Columns (46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 =  pd.read_csv('project3_m.csv', parse_dates = ["DATE"], date_format = '%Y-%m-%dT%H:%M:%S')

# %%
df3 =  pd.read_csv('project3_c.csv', parse_dates = ["DATE"], date_format = '%Y-%m-%dT%H:%M:%S')
df3 = df3.set_index("DATE")
# Out:
# C:\Users\ziyi Su\AppData\Local\Temp\ipykernel_7468\2741557818.py:1: DtypeWarning: Columns (7,15,16,30,31,36,40,41,45,46,47,48,49,50,51,64,67,82,84,86,89,91) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 =  pd.read_csv('project3_c.csv', parse_dates = ["DATE"], date_format = '%Y-%m-%dT%H:%M:%S')

# %%
df_merge = pd.concat([df2,df3], axis=0)
df_merge
# Out:
#                          STATION                                NAME  \
# DATE
# 2010-01-01 00:53:00  72202012839  MIAMI INTERNATIONAL AIRPORT, FL US
# 2010-01-01 01:00:00  72202012839  MIAMI INTERNATIONAL AIRPORT, FL US
# 2010-01-01 01:53:00  72202012839  MIAMI INTERNATIONAL AIRPORT, FL US
# 2010-01-01 02:53:00  72202012839  MIAMI INTERNATIONAL AIRPORT, FL US
# 2010-01-01 03:53:00  72202012839  MIAMI INTERNATIONAL AIRPORT, FL US
# ...                          ...                                 ...
# 2020-01-01 21:00:00  72534014819       CHICAGO MIDWAY AIRPORT, IL US
# 2020-01-01 21:53:00  72534014819       CHICAGO MIDWAY AIRPORT, IL US
# 2020-01-01 22:53:00  72534014819       CHICAGO MIDWAY AIRPORT, IL US
# 2020-01-01 23:53:00  72534014819       CHICAGO MIDWAY AIRPORT, IL US
# 2020-01-01 23:59:00  72534014819       CHICAGO MIDWAY AIRPORT, IL US
#
#                      LATITUDE  LONGITUDE  ELEVATION REPORT_TYPE SOURCE  AWND  \
# DATE
# 2010-01-01 00:53:00  25.78805  -80.31694        1.4       FM-15      7   NaN
# 2010-01-01 01:00:00  25.78805  -80.31694        1.4       FM-12      4   NaN
# 2010-01-01 01:53:00  25.78805  -80.31694        1.4       FM-15      7   NaN
# 2010-01-01 02:53:00  25.78805  -80.31694        1.4       FM-15      7   NaN
# 2010-01-01 03:53:00  25.78805  -80.31694        1.4       FM-15      7   NaN
# ...                       ...        ...        ...         ...    ...   ...
# 2020-01-01 21:00:00  41.78412  -87.75514      185.8       FM-12      4   NaN
# 2020-01-01 21:53:00  41.78412  -87.75514      185.8       FM-15      7   NaN
# 2020-01-01 22:53:00  41.78412  -87.75514      185.8       FM-15      7   NaN
# 2020-01-01 23:53:00  41.78412  -87.75514      185.8       FM-15      7   NaN
# 2020-01-01 23:59:00  41.78412  -87.75514      185.8       SOD        6   NaN
#
#                      CDSD  CLDD  ...  ShortDurationPrecipitationValue060  \
# DATE                             ...
# 2010-01-01 00:53:00   NaN   NaN  ...                                 NaN
# 2010-01-01 01:00:00   NaN   NaN  ...                                 NaN
# 2010-01-01 01:53:00   NaN   NaN  ...                                 NaN
# 2010-01-01 02:53:00   NaN   NaN  ...                                 NaN
# 2010-01-01 03:53:00   NaN   NaN  ...                                 NaN
# ...                   ...   ...  ...                                 ...
# 2020-01-01 21:00:00   NaN   NaN  ...                                 NaN
# 2020-01-01 21:53:00   NaN   NaN  ...                                 NaN
# 2020-01-01 22:53:00   NaN   NaN  ...                                 NaN
# 2020-01-01 23:53:00   NaN   NaN  ...                                 NaN
# 2020-01-01 23:59:00   NaN   NaN  ...                                 NaN
#
#                      ShortDurationPrecipitationValue080  \
# DATE
# 2010-01-01 00:53:00                                 NaN
# 2010-01-01 01:00:00                                 NaN
# 2010-01-01 01:53:00                                 NaN
# 2010-01-01 02:53:00                                 NaN
# 2010-01-01 03:53:00                                 NaN
# ...                                                 ...
# 2020-01-01 21:00:00                                 NaN
# 2020-01-01 21:53:00                                 NaN
# 2020-01-01 22:53:00                                 NaN
# 2020-01-01 23:53:00                                 NaN
# 2020-01-01 23:59:00                                 NaN
#
#                      ShortDurationPrecipitationValue100  \
# DATE
# 2010-01-01 00:53:00                                 NaN
# 2010-01-01 01:00:00                                 NaN
# 2010-01-01 01:53:00                                 NaN
# 2010-01-01 02:53:00                                 NaN
# 2010-01-01 03:53:00                                 NaN
# ...                                                 ...
# 2020-01-01 21:00:00                                 NaN
# 2020-01-01 21:53:00                                 NaN
# 2020-01-01 22:53:00                                 NaN
# 2020-01-01 23:53:00                                 NaN
# 2020-01-01 23:59:00                                 NaN
#
#                      ShortDurationPrecipitationValue120  \
# DATE
# 2010-01-01 00:53:00                                 NaN
# 2010-01-01 01:00:00                                 NaN
# 2010-01-01 01:53:00                                 NaN
# 2010-01-01 02:53:00                                 NaN
# 2010-01-01 03:53:00                                 NaN
# ...                                                 ...
# 2020-01-01 21:00:00                                 NaN
# 2020-01-01 21:53:00                                 NaN
# 2020-01-01 22:53:00                                 NaN
# 2020-01-01 23:53:00                                 NaN
# 2020-01-01 23:59:00                                 NaN
#
#                      ShortDurationPrecipitationValue150  \
# DATE
# 2010-01-01 00:53:00                                 NaN
# 2010-01-01 01:00:00                                 NaN
# 2010-01-01 01:53:00                                 NaN
# 2010-01-01 02:53:00                                 NaN
# 2010-01-01 03:53:00                                 NaN
# ...                                                 ...
# 2020-01-01 21:00:00                                 NaN
# 2020-01-01 21:53:00                                 NaN
# 2020-01-01 22:53:00                                 NaN
# 2020-01-01 23:53:00                                 NaN
# 2020-01-01 23:59:00                                 NaN
#
#                      ShortDurationPrecipitationValue180  Sunrise  Sunset  \
# DATE
# 2010-01-01 00:53:00                                 NaN      NaN     NaN
# 2010-01-01 01:00:00                                 NaN      NaN     NaN
# 2010-01-01 01:53:00                                 NaN      NaN     NaN
# 2010-01-01 02:53:00                                 NaN      NaN     NaN
# 2010-01-01 03:53:00                                 NaN      NaN     NaN
# ...                                                 ...      ...     ...
# 2020-01-01 21:00:00                                 NaN      NaN     NaN
# 2020-01-01 21:53:00                                 NaN      NaN     NaN
# 2020-01-01 22:53:00                                 NaN      NaN     NaN
# 2020-01-01 23:53:00                                 NaN      NaN     NaN
# 2020-01-01 23:59:00                                 NaN    719.0  1631.0
#
#                      WindEquipmentChangeDate  DailySnowDepth
# DATE
# 2010-01-01 00:53:00               2009-07-14             NaN
# 2010-01-01 01:00:00               2009-07-14             NaN
# 2010-01-01 01:53:00               2009-07-14             NaN
# 2010-01-01 02:53:00               2009-07-14             NaN
# 2010-01-01 03:53:00               2009-07-14             NaN
# ...                                      ...             ...
# 2020-01-01 21:00:00               2007-06-13             NaN
# 2020-01-01 21:53:00               2007-06-13             NaN
# 2020-01-01 22:53:00               2007-06-13             NaN
# 2020-01-01 23:53:00               2007-06-13             NaN
# 2020-01-01 23:59:00               2007-06-13             NaN
#
# [257525 rows x 110 columns]

# %%
df_chicago = df_merge[(df_merge['Sunrise'].notna()) & (df_merge['Sunset'].notna()) & (df_merge['NAME'] == 'CHICAGO MIDWAY AIRPORT, IL US')]
df_miami = df_merge[(df_merge['Sunrise'].notna()) & (df_merge['Sunset'].notna()) & (df_merge['NAME'] == 'MIAMI INTERNATIONAL AIRPORT, FL US')]


plt.figure(figsize=(10, 6))
plt.plot(df_chicago.index,df_chicago['Sunrise'], label='Sunrise chicago')
plt.plot(df_chicago.index, df_chicago['Sunset'], label='Sunset chicago')
plt.plot(df_miami.index,df_miami['Sunrise'], label='Sunrise miami')
plt.plot(df_miami.index, df_miami['Sunset'], label='Sunset miami')
plt.title('Sunrise and Sunset Times Throughout the Year')
plt.xlabel('Date')
plt.ylabel('Time')
plt.legend()
plt.savefig('project3-3.png')
plt.show()
plt.close()

# %%
df_tm = df_merge[(df_merge['DailyAverageDryBulbTemperature'].notna()) & (df_merge['NAME'] == 'MIAMI INTERNATIONAL AIRPORT, FL US')].copy()
df_tc = df_merge[(df_merge['DailyAverageDryBulbTemperature'].notna()) & (df_merge['NAME'] == 'CHICAGO MIDWAY AIRPORT, IL US')].copy()


plt.figure(figsize=(10, 6))
plt.plot(df_tc.index,df_tc['DailyAverageDryBulbTemperature'], label='temperature chicago')
plt.plot(df_tm.index, df_tm['DailyAverageDryBulbTemperature'], label='temperature miami')
plt.title('Temperature comparison')
plt.xlabel('Date')
plt.ylabel('temperature')
plt.legend()
plt.savefig('project3-4.png')
plt.show()
plt.close()

# %%
df_merge['difference_t'] = df_merge['Sunset'] - df_merge['Sunrise']

# %%
plt.figure(figsize=(10, 5))
sns.lmplot(x='difference_t', y='DailyMaximumDryBulbTemperature', data=df_merge, line_kws={'color': 'blue'})
#plt.scatter(df2['facecream'], df2['facewash'])
plt.xlabel('time of the sun')
plt.ylabel('temperature')
plt.title('Relationship Between sun heat and temperature')
plt.savefig('project3-5.png')
plt.show()
plt.close()
